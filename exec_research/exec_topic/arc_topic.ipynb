# %% [markdown]
# #### Import Package

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from matplotlib.patches import Arc

from class_data.data import Data
from class_generate.gen_emb import GenEmb
from utils.system import get_format_data

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load Data

# %%
topics = pd.read_csv('../../plot/esg_index/topic.csv').reset_index(drop=True)
topics['Timestamp'] = pd.to_datetime(pd.to_datetime(topics['Timestamp']).dt.strftime('%Y-%m-%d'))
topics.columns = ['topic', 'words', 'freq', 'date']
topics = topics.set_index('date')

# %% [markdown]
# #### Generate Arc

# %%
df = topics.loc[topics.topic == 1]

# %%
df
# Out:
#             topic                                              words  freq
# date
# 1985-11-25      1                    ozone, air, angeles, los, areas     1
# 1987-10-20      1  warming, environment, hunting, conservation, e...     4
# 1989-09-13      1             royalties, park, coal, formula, wastes     3
# 1991-08-08      1  environmental, pollution, nitrogen, scientists...     8
# 1993-07-02      1  pollution, credits, plan, environmental, emiss...     7
# 1995-05-27      1  air, conditioners, conditioning, baku, bakkond...     2
# 1997-04-20      1    emissions, treaty, warming, greenhouse, dioxide     9
# 1999-03-15      1            emissions, kyoto, treaty, gases, energy     7
# 2001-02-06      1     kyoto, emissions, bush, environmental, warming    13
# 2003-01-01      1  emissions, warming, globalwarming, dioxide, vo...    13
# 2004-11-24      1           climate, global, energy, warming, change     8
# ...
