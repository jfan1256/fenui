# %% [markdown]
# #### Import Package

# %%
import chromadb
import time
import os
import pandas as pd
import numpy as np
import ray

from chromadb.config import Settings
from chromadb.utils import embedding_functions
from datetime import datetime

from utils.system import *
from class_data.data import Data

# %% [markdown]
# #### Export Data

# %% [markdown]
# ##### --> Make sure to run format_data.ipynb and get_emb_openai.ipynb (chronologically) to get the data for this
# ###### --> Skip this if the data is already provided

# %%
# Multiple Articles per Day Open AI Embeddings
wsj_multiple_openai = Data(folder_path=get_format_data() / 'openai', file_pattern='wsj_emb_openai_*')
wsj_multiple_openai = wsj_multiple_openai.concat_files()
print(wsj_multiple_openai.shape)
# Multiple Articles per Day Data
wsj_multiple = Data(folder_path=get_format_data() / 'token', file_pattern='wsj_tokens_*')
wsj_multiple = wsj_multiple.concat_files()
print(wsj_multiple.shape)

# %%
# Merge Embeddings and Article
wsj_combine = pd.concat([wsj_multiple_openai, wsj_multiple], axis=1)

# %%
# Set limit to the exact same value used in embedding_similarity.ipynb to align indexes
limit = 30
count = wsj_combine.groupby(wsj_combine.index)['accession_number'].count()
valid_dates_mask = count >= limit
wsj_combine = wsj_combine[wsj_combine.index.isin(count[valid_dates_mask].index)]
print(wsj_combine.shape)

# %%
# Add IDs
wsj_combine = wsj_combine.reset_index()
wsj_combine = wsj_combine.rename(columns={'index':'date'})
wsj_combine.index.names = ['id']
wsj_combine = wsj_combine.reset_index().set_index(['id', 'date'])
# Add article count
wsj_combine['article_count'] = wsj_combine.groupby(level='date')['body_txt'].transform('count')

# %%
# Export Data
chunks = np.array_split(wsj_combine, 50)
for i, df in enumerate(chunks, 1):
    print(i)
    df.to_parquet(get_format_data() / 'web' / f'wsj_all_{i}.parquet.brotli', compression='brotli')

# %% [markdown]
# #### Load Data

# %%
# Multiple Articles per Day Open AI Embeddings
wsj_combine = Data(folder_path=get_format_data() / 'web', file_pattern='wsj_all_*')
wsj_combine = wsj_combine.concat_files()
wsj_combine.shape
# Out:
# (830899, 6)

# %% [markdown]
# #### Create ChromaDB

# %%
# Create Database in get_backend() directory
os.environ['ALLOW_RESET'] = 'TRUE'
client = chromadb.PersistentClient(path=str(get_backend_chromadb()))

# %%
# Delete Collection
client.delete_collection(name="wsj_emb")

# %%
# List Collection
client.list_collections()
# Out:
# []

# %% [markdown]
# #### ChromDB Add Data (Parallelized)

# %%
@ray.remote
def db_add_group(group):
    # Create/Get database in get_backend() directory
    os.environ['ALLOW_RESET'] = 'TRUE'
    client = chromadb.PersistentClient(path=str(get_backend_chromadb()))
    
    # Create OpenAI embedding function
    openai_ef = embedding_functions.OpenAIEmbeddingFunction(
                    model_name="text-embedding-ada-002",
                    api_key='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'
                )
    
    # Create/Get Collection
    collection = client.get_or_create_collection(name="wsj_emb", embedding_function=openai_ef, metadata={"hnsw:space": "cosine"})    
    
    # Create lists for bulk insertion
    embeddings = []
    documents = []
    metadatas = []
    ids = []
    for row in group.iterrows():
        embeddings.append(row[1]['ada_embedding'].tolist())
        documents.append(row[1]['body_txt'])
        source = "wsj openai embedding"
        date_timestamp = int(time.mktime(row[0][1].timetuple()))
        metadatas.append({
            "source": source, 
            "date": date_timestamp,
            "headline": row[1]['headline'],
            "n_token": row[1]['n_tokens'],
            "n_date": row[1]['article_count']
        })
        ids.append(f"id{row[0][0]}")

    # Bulk add to collection
    collection.add(
        embeddings=embeddings,
        documents=documents,
        metadatas=metadatas,
        ids=ids
    )

def db_add_all(df, group_size, batch_size, progress_file):
    # Check if progress file exists and load processed batch numbers
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as file:
            processed_batches = {int(line.strip()) for line in file.readlines()}
    else:
        processed_batches = set()

    # Calculate the total number of groups and batches
    total_groups = np.ceil(len(df) / group_size)
    num_batches = np.ceil(total_groups / batch_size)
    print(f"Total groups: {int(total_groups)}, Number of batches: {int(num_batches)}")

    for batch_idx in range(int(num_batches)):
        # Log batch
        print("-" * 60)
        print(f"Processing batch: {batch_idx + 1}/{int(num_batches)}")

        # Check if this batch has already been processed
        if batch_idx in processed_batches:
            print(f"Already processed (skipping): Batch {batch_idx + 1}")
            continue

        # Collect groups: len(futures) = batch_size
        futures = []
        for group_idx in range(batch_idx * batch_size, min((batch_idx + 1) * batch_size, int(total_groups))):
            # Create groups: len(group) = group_size
            group_start = group_idx * group_size
            group_end = min(group_start + group_size, len(df))
            group = df[group_start:group_end]
            future = db_add_group.remote(group)
            futures.append(future)

        # Parallelize tasks across groups
        ray.get(futures)

        # Update progress file with the completed batch number
        with open(progress_file, 'a') as file:
            file.write(f"{batch_idx}\n")

# %%
# Process articles in batches
start_time = time.time()
ray.init(num_cpus=16, ignore_reinit_error=True)
# Create Progress File
progress_file = get_backend_data() / "progress_chroma_db.txt"
db_add_all(df=wsj_combine, group_size=500, batch_size=50, progress_file=progress_file)
elasped_time = time.time() - start_time
print(f"Total Time: {elasped_time} seconds")
# Shutdown Ray
ray.shutdown()
# Out:
# 2024-01-13 00:37:24,911	INFO worker.py:1673 -- Started a local Ray instance.
# Number of batches: 8309
# ------------------------------------------------------------
# Processing batch: 1/8309
# ------------------------------------------------------------
# Processing batch: 2/8309
# ------------------------------------------------------------
# Processing batch: 3/8309
# ------------------------------------------------------------
# Processing batch: 4/8309
# ------------------------------------------------------------
# Processing batch: 5/8309
# ------------------------------------------------------------
# Processing batch: 6/8309
# ------------------------------------------------------------
# Processing batch: 7/8309
# ------------------------------------------------------------
# Processing batch: 8/8309
# ------------------------------------------------------------
# Processing batch: 9/8309
# ------------------------------------------------------------
# Processing batch: 10/8309
# ------------------------------------------------------------
# Processing batch: 11/8309
# ------------------------------------------------------------
# Processing batch: 12/8309
# ------------------------------------------------------------
# Processing batch: 13/8309
# ------------------------------------------------------------
# Processing batch: 14/8309
# ------------------------------------------------------------
# Processing batch: 15/8309
# ------------------------------------------------------------
# Processing batch: 16/8309
# ------------------------------------------------------------
# Processing batch: 17/8309
# ------------------------------------------------------------
# Processing batch: 18/8309
# ------------------------------------------------------------
# Processing batch: 19/8309
# ------------------------------------------------------------
# Processing batch: 20/8309
# ------------------------------------------------------------
# Processing batch: 21/8309
# ------------------------------------------------------------
# Processing batch: 22/8309
# ------------------------------------------------------------
# Processing batch: 23/8309
# ------------------------------------------------------------
# Processing batch: 24/8309
# ------------------------------------------------------------
# Processing batch: 25/8309
# ------------------------------------------------------------
# Processing batch: 26/8309
# ------------------------------------------------------------
# Processing batch: 27/8309
# ------------------------------------------------------------
# Processing batch: 28/8309
# ------------------------------------------------------------
# Processing batch: 29/8309
# ------------------------------------------------------------
# Processing batch: 30/8309
# ------------------------------------------------------------
# Processing batch: 31/8309
# ------------------------------------------------------------
# Processing batch: 32/8309
# ------------------------------------------------------------
# Processing batch: 33/8309
# ------------------------------------------------------------
# Processing batch: 34/8309
# ------------------------------------------------------------
# Processing batch: 35/8309
# ------------------------------------------------------------
# Processing batch: 36/8309
# ------------------------------------------------------------
# Processing batch: 37/8309
# ------------------------------------------------------------
# Processing batch: 38/8309
# ------------------------------------------------------------
# Processing batch: 39/8309
# ------------------------------------------------------------
# Processing batch: 40/8309
# ------------------------------------------------------------
# Processing batch: 41/8309
# ------------------------------------------------------------
# Processing batch: 42/8309
# ------------------------------------------------------------
# Processing batch: 43/8309
# ------------------------------------------------------------
# Processing batch: 44/8309
# ------------------------------------------------------------
# Processing batch: 45/8309
# ------------------------------------------------------------
# Processing batch: 46/8309
# ------------------------------------------------------------
# Processing batch: 47/8309
# ------------------------------------------------------------
# Processing batch: 48/8309
# ------------------------------------------------------------
# Processing batch: 49/8309
# ------------------------------------------------------------
# Processing batch: 50/8309
# ------------------------------------------------------------
# Processing batch: 51/8309
# ------------------------------------------------------------
# Processing batch: 52/8309
# ------------------------------------------------------------
# Processing batch: 53/8309
# ------------------------------------------------------------
# Processing batch: 54/8309
# ------------------------------------------------------------
# Processing batch: 55/8309
# ------------------------------------------------------------
# Processing batch: 56/8309
# ------------------------------------------------------------
# Processing batch: 57/8309
# ------------------------------------------------------------
# Processing batch: 58/8309
# ------------------------------------------------------------
# Processing batch: 59/8309
# ------------------------------------------------------------
# Processing batch: 60/8309
# ------------------------------------------------------------
# Processing batch: 61/8309
# ------------------------------------------------------------
# Processing batch: 62/8309
# ------------------------------------------------------------
# Processing batch: 63/8309
# ------------------------------------------------------------
# Processing batch: 64/8309
# ------------------------------------------------------------
# Processing batch: 65/8309
# ------------------------------------------------------------
# Processing batch: 66/8309
# ------------------------------------------------------------
# Processing batch: 67/8309
# ------------------------------------------------------------
# Processing batch: 68/8309
# ------------------------------------------------------------
# Processing batch: 69/8309
# ------------------------------------------------------------
# Processing batch: 70/8309
# ------------------------------------------------------------
# Processing batch: 71/8309
# ------------------------------------------------------------
# Processing batch: 72/8309
# ------------------------------------------------------------
# Processing batch: 73/8309
# ------------------------------------------------------------
# Processing batch: 74/8309
# ------------------------------------------------------------
# Processing batch: 75/8309
# ------------------------------------------------------------
# Processing batch: 76/8309
# ------------------------------------------------------------
# Processing batch: 77/8309
# ------------------------------------------------------------
# Processing batch: 78/8309
# ------------------------------------------------------------
# Processing batch: 79/8309
# ------------------------------------------------------------
# Processing batch: 80/8309
# ------------------------------------------------------------
# Processing batch: 81/8309
# ------------------------------------------------------------
# Processing batch: 82/8309
# ------------------------------------------------------------
# Processing batch: 83/8309
# ------------------------------------------------------------
# Processing batch: 84/8309
# ------------------------------------------------------------
# Processing batch: 85/8309
# ------------------------------------------------------------
# Processing batch: 86/8309
# ------------------------------------------------------------
# Processing batch: 87/8309
# ------------------------------------------------------------
# Processing batch: 88/8309
# ------------------------------------------------------------
# Processing batch: 89/8309
# ------------------------------------------------------------
# Processing batch: 90/8309
# ------------------------------------------------------------
# Processing batch: 91/8309
# ------------------------------------------------------------
# Processing batch: 92/8309
# ------------------------------------------------------------
# Processing batch: 93/8309
# ------------------------------------------------------------
# Processing batch: 94/8309
# ------------------------------------------------------------
# Processing batch: 95/8309
# ------------------------------------------------------------
# Processing batch: 96/8309
# ------------------------------------------------------------
# Processing batch: 97/8309
# ------------------------------------------------------------
# Processing batch: 98/8309
# ------------------------------------------------------------
# Processing batch: 99/8309
# ------------------------------------------------------------
# Processing batch: 100/8309
# ------------------------------------------------------------
# Processing batch: 101/8309
# ------------------------------------------------------------
# Processing batch: 102/8309
# ------------------------------------------------------------
# Processing batch: 103/8309
# ------------------------------------------------------------
# Processing batch: 104/8309
# ------------------------------------------------------------
# Processing batch: 105/8309
# ------------------------------------------------------------
# Processing batch: 106/8309
# ------------------------------------------------------------
# Processing batch: 107/8309
# ------------------------------------------------------------
# Processing batch: 108/8309
# ------------------------------------------------------------
# Processing batch: 109/8309
# ------------------------------------------------------------
# Processing batch: 110/8309
# ------------------------------------------------------------
# Processing batch: 111/8309
# ------------------------------------------------------------
# Processing batch: 112/8309
# ------------------------------------------------------------
# Processing batch: 113/8309
# ------------------------------------------------------------
# Processing batch: 114/8309
# ------------------------------------------------------------
# Processing batch: 115/8309
# ------------------------------------------------------------
# Processing batch: 116/8309
# ------------------------------------------------------------
# Processing batch: 117/8309
# ------------------------------------------------------------
# Processing batch: 118/8309
# ------------------------------------------------------------
# Processing batch: 119/8309
# ------------------------------------------------------------
# Processing batch: 120/8309
# ------------------------------------------------------------
# Processing batch: 121/8309
# ------------------------------------------------------------
# Processing batch: 122/8309
# ------------------------------------------------------------
# Processing batch: 123/8309
# ------------------------------------------------------------
# Processing batch: 124/8309
# ------------------------------------------------------------
# Processing batch: 125/8309
# ------------------------------------------------------------
# Processing batch: 126/8309
# ------------------------------------------------------------
# Processing batch: 127/8309
# ------------------------------------------------------------
# Processing batch: 128/8309
# ------------------------------------------------------------
# Processing batch: 129/8309
# ------------------------------------------------------------
# Processing batch: 130/8309
# ------------------------------------------------------------
# Processing batch: 131/8309
# ------------------------------------------------------------
# Processing batch: 132/8309
# ------------------------------------------------------------
# Processing batch: 133/8309
# ------------------------------------------------------------
# Processing batch: 134/8309
# ------------------------------------------------------------
# Processing batch: 135/8309
# ------------------------------------------------------------
# Processing batch: 136/8309
# ------------------------------------------------------------
# Processing batch: 137/8309
# ------------------------------------------------------------
# Processing batch: 138/8309
# ------------------------------------------------------------
# Processing batch: 139/8309
# ------------------------------------------------------------
# Processing batch: 140/8309
# ------------------------------------------------------------
# Processing batch: 141/8309
# ------------------------------------------------------------
# Processing batch: 142/8309
# ------------------------------------------------------------
# Processing batch: 143/8309
# ------------------------------------------------------------
# Processing batch: 144/8309
# ------------------------------------------------------------
# Processing batch: 145/8309
# ------------------------------------------------------------
# Processing batch: 146/8309
# ------------------------------------------------------------
# Processing batch: 147/8309
# ------------------------------------------------------------
# Processing batch: 148/8309
# ------------------------------------------------------------
# Processing batch: 149/8309
# ------------------------------------------------------------
# Processing batch: 150/8309
# ------------------------------------------------------------
# Processing batch: 151/8309
# ------------------------------------------------------------
# Processing batch: 152/8309
# ------------------------------------------------------------
# Processing batch: 153/8309
# ------------------------------------------------------------
# Processing batch: 154/8309
# ------------------------------------------------------------
# Processing batch: 155/8309
# ------------------------------------------------------------
# Processing batch: 156/8309
# ------------------------------------------------------------
# Processing batch: 157/8309
# ------------------------------------------------------------
# Processing batch: 158/8309
# ------------------------------------------------------------
# Processing batch: 159/8309
# ------------------------------------------------------------
# Processing batch: 160/8309
# ------------------------------------------------------------
# Processing batch: 161/8309
# ------------------------------------------------------------
# Processing batch: 162/8309
# ------------------------------------------------------------
# Processing batch: 163/8309
# ------------------------------------------------------------
# Processing batch: 164/8309
# ------------------------------------------------------------
# Processing batch: 165/8309
# ------------------------------------------------------------
# Processing batch: 166/8309
# ------------------------------------------------------------
# Processing batch: 167/8309
# ------------------------------------------------------------
# Processing batch: 168/8309
# ------------------------------------------------------------
# Processing batch: 169/8309
# ------------------------------------------------------------
# Processing batch: 170/8309
# ------------------------------------------------------------
# Processing batch: 171/8309
# ------------------------------------------------------------
# Processing batch: 172/8309
# ------------------------------------------------------------
# Processing batch: 173/8309
# ------------------------------------------------------------
# Processing batch: 174/8309
# ------------------------------------------------------------
# Processing batch: 175/8309
# ------------------------------------------------------------
# Processing batch: 176/8309
# ------------------------------------------------------------
# Processing batch: 177/8309
# ------------------------------------------------------------
# Processing batch: 178/8309
# ------------------------------------------------------------
# Processing batch: 179/8309
# ------------------------------------------------------------
# Processing batch: 180/8309
# ------------------------------------------------------------
# Processing batch: 181/8309
# ------------------------------------------------------------
# Processing batch: 182/8309
# ------------------------------------------------------------
# Processing batch: 183/8309
# ------------------------------------------------------------
# Processing batch: 184/8309
# ------------------------------------------------------------
# Processing batch: 185/8309
# ------------------------------------------------------------
# Processing batch: 186/8309
# ------------------------------------------------------------
# Processing batch: 187/8309
# ------------------------------------------------------------
# Processing batch: 188/8309
# ------------------------------------------------------------
# Processing batch: 189/8309
# ------------------------------------------------------------
# Processing batch: 190/8309
# ------------------------------------------------------------
# Processing batch: 191/8309
# ------------------------------------------------------------
# Processing batch: 192/8309
# ------------------------------------------------------------
# Processing batch: 193/8309
# ------------------------------------------------------------
# Processing batch: 194/8309
# ------------------------------------------------------------
# Processing batch: 195/8309
# ------------------------------------------------------------
# Processing batch: 196/8309
# ------------------------------------------------------------
# Processing batch: 197/8309
# ------------------------------------------------------------
# Processing batch: 198/8309
# ------------------------------------------------------------
# Processing batch: 199/8309
# ------------------------------------------------------------
# Processing batch: 200/8309
# ------------------------------------------------------------
# Processing batch: 201/8309
# ------------------------------------------------------------
# Processing batch: 202/8309
# ------------------------------------------------------------
# Processing batch: 203/8309
# ------------------------------------------------------------
# Processing batch: 204/8309
# ------------------------------------------------------------
# Processing batch: 205/8309
# ------------------------------------------------------------
# Processing batch: 206/8309
# ------------------------------------------------------------
# Processing batch: 207/8309
# ------------------------------------------------------------
# Processing batch: 208/8309
# ------------------------------------------------------------
# Processing batch: 209/8309
# ------------------------------------------------------------
# Processing batch: 210/8309
# ------------------------------------------------------------
# Processing batch: 211/8309
# ------------------------------------------------------------
# Processing batch: 212/8309
# ------------------------------------------------------------
# Processing batch: 213/8309
# ------------------------------------------------------------
# Processing batch: 214/8309
# ------------------------------------------------------------
# Processing batch: 215/8309
# ------------------------------------------------------------
# Processing batch: 216/8309
# ------------------------------------------------------------
# Processing batch: 217/8309
# ------------------------------------------------------------
# Processing batch: 218/8309
# ------------------------------------------------------------
# Processing batch: 219/8309
# ------------------------------------------------------------
# Processing batch: 220/8309
# ------------------------------------------------------------
# Processing batch: 221/8309
# ------------------------------------------------------------
# Processing batch: 222/8309
# ------------------------------------------------------------
# Processing batch: 223/8309
# ------------------------------------------------------------
# Processing batch: 224/8309
# ------------------------------------------------------------
# Processing batch: 225/8309
# ------------------------------------------------------------
# Processing batch: 226/8309
# ------------------------------------------------------------
# Processing batch: 227/8309
# ------------------------------------------------------------
# Processing batch: 228/8309
# ------------------------------------------------------------
# Processing batch: 229/8309
# ------------------------------------------------------------
# Processing batch: 230/8309
# ------------------------------------------------------------
# Processing batch: 231/8309
# ------------------------------------------------------------
# Processing batch: 232/8309
# ------------------------------------------------------------
# Processing batch: 233/8309
# ------------------------------------------------------------
# Processing batch: 234/8309
# ------------------------------------------------------------
# Processing batch: 235/8309
# ------------------------------------------------------------
# Processing batch: 236/8309
# ------------------------------------------------------------
# Processing batch: 237/8309
# ------------------------------------------------------------
# Processing batch: 238/8309
# ------------------------------------------------------------
# Processing batch: 239/8309
# ------------------------------------------------------------
# Processing batch: 240/8309
# ------------------------------------------------------------
# Processing batch: 241/8309
# ------------------------------------------------------------
# Processing batch: 242/8309
# ------------------------------------------------------------
# Processing batch: 243/8309
# ------------------------------------------------------------
# Processing batch: 244/8309
# ------------------------------------------------------------
# Processing batch: 245/8309
# ------------------------------------------------------------
# Processing batch: 246/8309
# ------------------------------------------------------------
# Processing batch: 247/8309
# ------------------------------------------------------------
# Processing batch: 248/8309
# ------------------------------------------------------------
# Processing batch: 249/8309
# ------------------------------------------------------------
# Processing batch: 250/8309
# ------------------------------------------------------------
# Processing batch: 251/8309
# ------------------------------------------------------------
# Processing batch: 252/8309
# ------------------------------------------------------------
# Processing batch: 253/8309
# ------------------------------------------------------------
# Processing batch: 254/8309
# ------------------------------------------------------------
# Processing batch: 255/8309
# ------------------------------------------------------------
# Processing batch: 256/8309
# ------------------------------------------------------------
# Processing batch: 257/8309
# ------------------------------------------------------------
# Processing batch: 258/8309
# ------------------------------------------------------------
# Processing batch: 259/8309
# ------------------------------------------------------------
# Processing batch: 260/8309
# ------------------------------------------------------------
# Processing batch: 261/8309
# ------------------------------------------------------------
# Processing batch: 262/8309
# ------------------------------------------------------------
# Processing batch: 263/8309
# ------------------------------------------------------------
# Processing batch: 264/8309
# ------------------------------------------------------------
# Processing batch: 265/8309
# ------------------------------------------------------------
# Processing batch: 266/8309
# ------------------------------------------------------------
# Processing batch: 267/8309
# ------------------------------------------------------------
# Processing batch: 268/8309
# ------------------------------------------------------------
# Processing batch: 269/8309
# ------------------------------------------------------------
# Processing batch: 270/8309
# ------------------------------------------------------------
# Processing batch: 271/8309
# ------------------------------------------------------------
# Processing batch: 272/8309
# ------------------------------------------------------------
# Processing batch: 273/8309
# ------------------------------------------------------------
# Processing batch: 274/8309
# ------------------------------------------------------------
# Processing batch: 275/8309
# ------------------------------------------------------------
# Processing batch: 276/8309
# ------------------------------------------------------------
# Processing batch: 277/8309
# ------------------------------------------------------------
# Processing batch: 278/8309
# ------------------------------------------------------------
# Processing batch: 279/8309
# ------------------------------------------------------------
# Processing batch: 280/8309
# ------------------------------------------------------------
# Processing batch: 281/8309
# ------------------------------------------------------------
# Processing batch: 282/8309
# ------------------------------------------------------------
# Processing batch: 283/8309
# ------------------------------------------------------------
# Processing batch: 284/8309
# ------------------------------------------------------------
# Processing batch: 285/8309
# ------------------------------------------------------------
# Processing batch: 286/8309
# ------------------------------------------------------------
# Processing batch: 287/8309
# ------------------------------------------------------------
# Processing batch: 288/8309
# ------------------------------------------------------------
# Processing batch: 289/8309
# ------------------------------------------------------------
# Processing batch: 290/8309
# ------------------------------------------------------------
# Processing batch: 291/8309
# ------------------------------------------------------------
# Processing batch: 292/8309
# ------------------------------------------------------------
# Processing batch: 293/8309
# ------------------------------------------------------------
# Processing batch: 294/8309
# ------------------------------------------------------------
# Processing batch: 295/8309
# ------------------------------------------------------------
# Processing batch: 296/8309
# ------------------------------------------------------------
# Processing batch: 297/8309
# ------------------------------------------------------------
# Processing batch: 298/8309
# ------------------------------------------------------------
# Processing batch: 299/8309
# ------------------------------------------------------------
# Processing batch: 300/8309
# ------------------------------------------------------------
# Processing batch: 301/8309
# ------------------------------------------------------------
# Processing batch: 302/8309
# ------------------------------------------------------------
# Processing batch: 303/8309
# ------------------------------------------------------------
# Processing batch: 304/8309
# ------------------------------------------------------------
# Processing batch: 305/8309
# ------------------------------------------------------------
# Processing batch: 306/8309
# ------------------------------------------------------------
# Processing batch: 307/8309
# ------------------------------------------------------------
# Processing batch: 308/8309
# ------------------------------------------------------------
# Processing batch: 309/8309
# ------------------------------------------------------------
# Processing batch: 310/8309
# ------------------------------------------------------------
# Processing batch: 311/8309
# ------------------------------------------------------------
# Processing batch: 312/8309
# ------------------------------------------------------------
# Processing batch: 313/8309
# ------------------------------------------------------------
# Processing batch: 314/8309
# ------------------------------------------------------------
# Processing batch: 315/8309
# ------------------------------------------------------------
# Processing batch: 316/8309
# ------------------------------------------------------------
# Processing batch: 317/8309
# ------------------------------------------------------------
# Processing batch: 318/8309
# ------------------------------------------------------------
# Processing batch: 319/8309
# ------------------------------------------------------------
# Processing batch: 320/8309
# ------------------------------------------------------------
# Processing batch: 321/8309
# ------------------------------------------------------------
# Processing batch: 322/8309
# ------------------------------------------------------------
# Processing batch: 323/8309
# ------------------------------------------------------------
# Processing batch: 324/8309
# ------------------------------------------------------------
# Processing batch: 325/8309
# ------------------------------------------------------------
# Processing batch: 326/8309
# ------------------------------------------------------------
# Processing batch: 327/8309
# ------------------------------------------------------------
# Processing batch: 328/8309
# ------------------------------------------------------------
# Processing batch: 329/8309
# ------------------------------------------------------------
# Processing batch: 330/8309
# ------------------------------------------------------------
# Processing batch: 331/8309
# ------------------------------------------------------------
# Processing batch: 332/8309
# ------------------------------------------------------------
# Processing batch: 333/8309
# ------------------------------------------------------------
# Processing batch: 334/8309
# ------------------------------------------------------------
# Processing batch: 335/8309
# ------------------------------------------------------------
# Processing batch: 336/8309
# ------------------------------------------------------------
# Processing batch: 337/8309
# ------------------------------------------------------------
# Processing batch: 338/8309
# ------------------------------------------------------------
# Processing batch: 339/8309
# ------------------------------------------------------------
# Processing batch: 340/8309
# ------------------------------------------------------------
# Processing batch: 341/8309
# ------------------------------------------------------------
# Processing batch: 342/8309
# ------------------------------------------------------------
# Processing batch: 343/8309
# ------------------------------------------------------------
# Processing batch: 344/8309
# ------------------------------------------------------------
# Processing batch: 345/8309
# ------------------------------------------------------------
# Processing batch: 346/8309
# ------------------------------------------------------------
# Processing batch: 347/8309
# ------------------------------------------------------------
# Processing batch: 348/8309
# ------------------------------------------------------------
# Processing batch: 349/8309
# ------------------------------------------------------------
# Processing batch: 350/8309
# ------------------------------------------------------------
# Processing batch: 351/8309
# ------------------------------------------------------------
# Processing batch: 352/8309
# ------------------------------------------------------------
# Processing batch: 353/8309
# ------------------------------------------------------------
# Processing batch: 354/8309
# ------------------------------------------------------------
# Processing batch: 355/8309
# ------------------------------------------------------------
# Processing batch: 356/8309
# ------------------------------------------------------------
# Processing batch: 357/8309
# ------------------------------------------------------------
# Processing batch: 358/8309
# ------------------------------------------------------------
# Processing batch: 359/8309
# ------------------------------------------------------------
# Processing batch: 360/8309
# ------------------------------------------------------------
# Processing batch: 361/8309
# ------------------------------------------------------------
# Processing batch: 362/8309
# ------------------------------------------------------------
# Processing batch: 363/8309
# ------------------------------------------------------------
# Processing batch: 364/8309
# ------------------------------------------------------------
# Processing batch: 365/8309
# ------------------------------------------------------------
# Processing batch: 366/8309
# ------------------------------------------------------------
# Processing batch: 367/8309
# ------------------------------------------------------------
# Processing batch: 368/8309
# ------------------------------------------------------------
# Processing batch: 369/8309
# ------------------------------------------------------------
# Processing batch: 370/8309
# ------------------------------------------------------------
# Processing batch: 371/8309
# ------------------------------------------------------------
# Processing batch: 372/8309
# ------------------------------------------------------------
# Processing batch: 373/8309
# ------------------------------------------------------------
# Processing batch: 374/8309
# ------------------------------------------------------------
# Processing batch: 375/8309
# ------------------------------------------------------------
# Processing batch: 376/8309
# ------------------------------------------------------------
# Processing batch: 377/8309
# ------------------------------------------------------------
# Processing batch: 378/8309
# ------------------------------------------------------------
# Processing batch: 379/8309
# ------------------------------------------------------------
# Processing batch: 380/8309
# ------------------------------------------------------------
# Processing batch: 381/8309
# ------------------------------------------------------------
# Processing batch: 382/8309
# ------------------------------------------------------------
# Processing batch: 383/8309
# ------------------------------------------------------------
# Processing batch: 384/8309
# ------------------------------------------------------------
# Processing batch: 385/8309
# ------------------------------------------------------------
# Processing batch: 386/8309
# ------------------------------------------------------------
# Processing batch: 387/8309
# ------------------------------------------------------------
# Processing batch: 388/8309
# ------------------------------------------------------------
# Processing batch: 389/8309
# ------------------------------------------------------------
# Processing batch: 390/8309
# ------------------------------------------------------------
# Processing batch: 391/8309
# ------------------------------------------------------------
# Processing batch: 392/8309
# ------------------------------------------------------------
# Processing batch: 393/8309
# ------------------------------------------------------------
# Processing batch: 394/8309
# ------------------------------------------------------------
# Processing batch: 395/8309
# ------------------------------------------------------------
# Processing batch: 396/8309
# ------------------------------------------------------------
# Processing batch: 397/8309
# ------------------------------------------------------------
# Processing batch: 398/8309
# ------------------------------------------------------------
# Processing batch: 399/8309
# ------------------------------------------------------------
# Processing batch: 400/8309
# ------------------------------------------------------------
# Processing batch: 401/8309
# ------------------------------------------------------------
# Processing batch: 402/8309
# ------------------------------------------------------------
# Processing batch: 403/8309
# ------------------------------------------------------------
# Processing batch: 404/8309
# ------------------------------------------------------------
# Processing batch: 405/8309
# ------------------------------------------------------------
# Processing batch: 406/8309
# ------------------------------------------------------------
# Processing batch: 407/8309
# ------------------------------------------------------------
# Processing batch: 408/8309
# ------------------------------------------------------------
# Processing batch: 409/8309
# ------------------------------------------------------------
# Processing batch: 410/8309
# ------------------------------------------------------------
# Processing batch: 411/8309
# ------------------------------------------------------------
# Processing batch: 412/8309
# ------------------------------------------------------------
# Processing batch: 413/8309
# ------------------------------------------------------------
# Processing batch: 414/8309
# ------------------------------------------------------------
# Processing batch: 415/8309
# ------------------------------------------------------------
# Processing batch: 416/8309
# ------------------------------------------------------------
# Processing batch: 417/8309
# ------------------------------------------------------------
# Processing batch: 418/8309
# ------------------------------------------------------------
# Processing batch: 419/8309
# ------------------------------------------------------------
# Processing batch: 420/8309
# ------------------------------------------------------------
# Processing batch: 421/8309
# ------------------------------------------------------------
# Processing batch: 422/8309
# ------------------------------------------------------------
# Processing batch: 423/8309
# ------------------------------------------------------------
# Processing batch: 424/8309
# ------------------------------------------------------------
# Processing batch: 425/8309
# ------------------------------------------------------------
# Processing batch: 426/8309
# ------------------------------------------------------------
# Processing batch: 427/8309
# ------------------------------------------------------------
# Processing batch: 428/8309
# ------------------------------------------------------------
# Processing batch: 429/8309
# ------------------------------------------------------------
# Processing batch: 430/8309
# ------------------------------------------------------------
# Processing batch: 431/8309
# ------------------------------------------------------------
# Processing batch: 432/8309
# ------------------------------------------------------------
# Processing batch: 433/8309
# ------------------------------------------------------------
# Processing batch: 434/8309
# ------------------------------------------------------------
# Processing batch: 435/8309
# ------------------------------------------------------------
# Processing batch: 436/8309
# ------------------------------------------------------------
# Processing batch: 437/8309
# ------------------------------------------------------------
# Processing batch: 438/8309
# ------------------------------------------------------------
# Processing batch: 439/8309
# ------------------------------------------------------------
# Processing batch: 440/8309
# ------------------------------------------------------------
# Processing batch: 441/8309
# ------------------------------------------------------------
# Processing batch: 442/8309
# ------------------------------------------------------------
# Processing batch: 443/8309
# ------------------------------------------------------------
# Processing batch: 444/8309
# ------------------------------------------------------------
# Processing batch: 445/8309
# ------------------------------------------------------------
# Processing batch: 446/8309
# ------------------------------------------------------------
# Processing batch: 447/8309
# ------------------------------------------------------------
# Processing batch: 448/8309
# ------------------------------------------------------------
# Processing batch: 449/8309
# ------------------------------------------------------------
# Processing batch: 450/8309
# ------------------------------------------------------------
# Processing batch: 451/8309
# ------------------------------------------------------------
# Processing batch: 452/8309
# ------------------------------------------------------------
# Processing batch: 453/8309
# ------------------------------------------------------------
# Processing batch: 454/8309
# ------------------------------------------------------------
# Processing batch: 455/8309
# ------------------------------------------------------------
# Processing batch: 456/8309
# ------------------------------------------------------------
# Processing batch: 457/8309
# ------------------------------------------------------------
# Processing batch: 458/8309
# ------------------------------------------------------------
# Processing batch: 459/8309
# ------------------------------------------------------------
# Processing batch: 460/8309
# ------------------------------------------------------------
# Processing batch: 461/8309
# ------------------------------------------------------------
# Processing batch: 462/8309
# ------------------------------------------------------------
# Processing batch: 463/8309
# ------------------------------------------------------------
# Processing batch: 464/8309
# ------------------------------------------------------------
# Processing batch: 465/8309
# ------------------------------------------------------------
# Processing batch: 466/8309
# ------------------------------------------------------------
# Processing batch: 467/8309
# ------------------------------------------------------------
# Processing batch: 468/8309
# ------------------------------------------------------------
# Processing batch: 469/8309
# ------------------------------------------------------------
# Processing batch: 470/8309
# ------------------------------------------------------------
# Processing batch: 471/8309
# ------------------------------------------------------------
# Processing batch: 472/8309
# ------------------------------------------------------------
# Processing batch: 473/8309
# ------------------------------------------------------------
# Processing batch: 474/8309
# ------------------------------------------------------------
# Processing batch: 475/8309
# ------------------------------------------------------------
# Processing batch: 476/8309
# ------------------------------------------------------------
# Processing batch: 477/8309
# ------------------------------------------------------------
# Processing batch: 478/8309
# ------------------------------------------------------------
# Processing batch: 479/8309
# ------------------------------------------------------------
# Processing batch: 480/8309
# ------------------------------------------------------------
# Processing batch: 481/8309
# ------------------------------------------------------------
# Processing batch: 482/8309
# ------------------------------------------------------------
# Processing batch: 483/8309
# ------------------------------------------------------------
# Processing batch: 484/8309
# ------------------------------------------------------------
# Processing batch: 485/8309
# ------------------------------------------------------------
# Processing batch: 486/8309
# ------------------------------------------------------------
# Processing batch: 487/8309
# ------------------------------------------------------------
# Processing batch: 488/8309
# ------------------------------------------------------------
# Processing batch: 489/8309
# ------------------------------------------------------------
# Processing batch: 490/8309
# ------------------------------------------------------------
# Processing batch: 491/8309
# ------------------------------------------------------------
# Processing batch: 492/8309
# ------------------------------------------------------------
# Processing batch: 493/8309
# ------------------------------------------------------------
# Processing batch: 494/8309
# ------------------------------------------------------------
# Processing batch: 495/8309
# ------------------------------------------------------------
# Processing batch: 496/8309
# ------------------------------------------------------------
# Processing batch: 497/8309
# ------------------------------------------------------------
# Processing batch: 498/8309
# ------------------------------------------------------------
# Processing batch: 499/8309
# ------------------------------------------------------------
# Processing batch: 500/8309
# ------------------------------------------------------------
# Processing batch: 501/8309
# ------------------------------------------------------------
# Processing batch: 502/8309
# ------------------------------------------------------------
# Processing batch: 503/8309
# ------------------------------------------------------------
# Processing batch: 504/8309
# ------------------------------------------------------------
# Processing batch: 505/8309
# ------------------------------------------------------------
# Processing batch: 506/8309
# ------------------------------------------------------------
# Processing batch: 507/8309
# ------------------------------------------------------------
# Processing batch: 508/8309
# ------------------------------------------------------------
# Processing batch: 509/8309
# ------------------------------------------------------------
# Processing batch: 510/8309
# ------------------------------------------------------------
# Processing batch: 511/8309
# ------------------------------------------------------------
# Processing batch: 512/8309
# ------------------------------------------------------------
# Processing batch: 513/8309
# ------------------------------------------------------------
# Processing batch: 514/8309
# ------------------------------------------------------------
# Processing batch: 515/8309
# ------------------------------------------------------------
# Processing batch: 516/8309
# ------------------------------------------------------------
# Processing batch: 517/8309
# ------------------------------------------------------------
# Processing batch: 518/8309
# ------------------------------------------------------------
# Processing batch: 519/8309
# ------------------------------------------------------------
# Processing batch: 520/8309
# ------------------------------------------------------------
# Processing batch: 521/8309
# ------------------------------------------------------------
# Processing batch: 522/8309
# ------------------------------------------------------------
# Processing batch: 523/8309
# ------------------------------------------------------------
# Processing batch: 524/8309
# ------------------------------------------------------------
# Processing batch: 525/8309
# ------------------------------------------------------------
# Processing batch: 526/8309
# ------------------------------------------------------------
# Processing batch: 527/8309
# ------------------------------------------------------------
# Processing batch: 528/8309
# ------------------------------------------------------------
# Processing batch: 529/8309
# ------------------------------------------------------------
# Processing batch: 530/8309
# ------------------------------------------------------------
# Processing batch: 531/8309
# ------------------------------------------------------------
# Processing batch: 532/8309
# ------------------------------------------------------------
# Processing batch: 533/8309
# ------------------------------------------------------------
# Processing batch: 534/8309
# ------------------------------------------------------------
# Processing batch: 535/8309
# ------------------------------------------------------------
# Processing batch: 536/8309
# ------------------------------------------------------------
# Processing batch: 537/8309
# ------------------------------------------------------------
# Processing batch: 538/8309
# ------------------------------------------------------------
# Processing batch: 539/8309
# ------------------------------------------------------------
# Processing batch: 540/8309
# ------------------------------------------------------------
# Processing batch: 541/8309
# ------------------------------------------------------------
# Processing batch: 542/8309
# ------------------------------------------------------------
# Processing batch: 543/8309
# ------------------------------------------------------------
# Processing batch: 544/8309
# ------------------------------------------------------------
# Processing batch: 545/8309
# ...
# Processing batch: 8130/8309
# ------------------------------------------------------------
# Processing batch: 8131/8309
# ------------------------------------------------------------
# Processing batch: 8132/8309
# ------------------------------------------------------------
# Processing batch: 8133/8309
# ------------------------------------------------------------
# Processing batch: 8134/8309
# ------------------------------------------------------------
# Processing batch: 8135/8309
# ------------------------------------------------------------
# Processing batch: 8136/8309
# ------------------------------------------------------------
# Processing batch: 8137/8309
# ------------------------------------------------------------
# Processing batch: 8138/8309
# ------------------------------------------------------------
# Processing batch: 8139/8309
# ------------------------------------------------------------
# Processing batch: 8140/8309
# ------------------------------------------------------------
# Processing batch: 8141/8309
# ------------------------------------------------------------
# Processing batch: 8142/8309
# ------------------------------------------------------------
# Processing batch: 8143/8309
# ------------------------------------------------------------
# Processing batch: 8144/8309
# ------------------------------------------------------------
# Processing batch: 8145/8309
# ------------------------------------------------------------
# Processing batch: 8146/8309
# ------------------------------------------------------------
# Processing batch: 8147/8309
# ------------------------------------------------------------
# Processing batch: 8148/8309
# ------------------------------------------------------------
# Processing batch: 8149/8309
# ------------------------------------------------------------
# Processing batch: 8150/8309
# ------------------------------------------------------------
# Processing batch: 8151/8309
# ------------------------------------------------------------
# Processing batch: 8152/8309
# ------------------------------------------------------------
# Processing batch: 8153/8309
# ------------------------------------------------------------
# Processing batch: 8154/8309
# ------------------------------------------------------------
# Processing batch: 8155/8309
# ------------------------------------------------------------
# Processing batch: 8156/8309
# ------------------------------------------------------------
# Processing batch: 8157/8309
# ------------------------------------------------------------
# Processing batch: 8158/8309
# ------------------------------------------------------------
# Processing batch: 8159/8309
# ------------------------------------------------------------
# Processing batch: 8160/8309
# ------------------------------------------------------------
# Processing batch: 8161/8309
# ------------------------------------------------------------
# Processing batch: 8162/8309
# ------------------------------------------------------------
# Processing batch: 8163/8309
# ------------------------------------------------------------
# Processing batch: 8164/8309
# ------------------------------------------------------------
# Processing batch: 8165/8309
# ------------------------------------------------------------
# Processing batch: 8166/8309
# ------------------------------------------------------------
# Processing batch: 8167/8309
# ------------------------------------------------------------
# Processing batch: 8168/8309
# ------------------------------------------------------------
# Processing batch: 8169/8309
# ------------------------------------------------------------
# Processing batch: 8170/8309
# ------------------------------------------------------------
# Processing batch: 8171/8309
# ------------------------------------------------------------
# Processing batch: 8172/8309
# ------------------------------------------------------------
# Processing batch: 8173/8309
# ------------------------------------------------------------
# Processing batch: 8174/8309
# ------------------------------------------------------------
# Processing batch: 8175/8309
# ------------------------------------------------------------
# Processing batch: 8176/8309
# ------------------------------------------------------------
# Processing batch: 8177/8309
# ------------------------------------------------------------
# Processing batch: 8178/8309
# ------------------------------------------------------------
# Processing batch: 8179/8309
# ------------------------------------------------------------
# Processing batch: 8180/8309
# ------------------------------------------------------------
# Processing batch: 8181/8309
# ------------------------------------------------------------
# Processing batch: 8182/8309
# ------------------------------------------------------------
# Processing batch: 8183/8309
# ------------------------------------------------------------
# Processing batch: 8184/8309
# ------------------------------------------------------------
# Processing batch: 8185/8309
# ------------------------------------------------------------
# Processing batch: 8186/8309
# ------------------------------------------------------------
# Processing batch: 8187/8309
# ------------------------------------------------------------
# Processing batch: 8188/8309
# ------------------------------------------------------------
# Processing batch: 8189/8309
# ------------------------------------------------------------
# Processing batch: 8190/8309
# ------------------------------------------------------------
# Processing batch: 8191/8309
# ------------------------------------------------------------
# Processing batch: 8192/8309
# ------------------------------------------------------------
# Processing batch: 8193/8309
# ------------------------------------------------------------
# Processing batch: 8194/8309
# ------------------------------------------------------------
# Processing batch: 8195/8309
# ------------------------------------------------------------
# Processing batch: 8196/8309
# ------------------------------------------------------------
# Processing batch: 8197/8309
# ------------------------------------------------------------
# Processing batch: 8198/8309
# ------------------------------------------------------------
# Processing batch: 8199/8309
# ------------------------------------------------------------
# Processing batch: 8200/8309
# ------------------------------------------------------------
# Processing batch: 8201/8309
# ------------------------------------------------------------
# Processing batch: 8202/8309
# ------------------------------------------------------------
# Processing batch: 8203/8309
# ------------------------------------------------------------
# Processing batch: 8204/8309
# ------------------------------------------------------------
# Processing batch: 8205/8309
# ------------------------------------------------------------
# Processing batch: 8206/8309
# ------------------------------------------------------------
# Processing batch: 8207/8309
# ------------------------------------------------------------
# Processing batch: 8208/8309
# ------------------------------------------------------------
# Processing batch: 8209/8309
# ------------------------------------------------------------
# Processing batch: 8210/8309
# ------------------------------------------------------------
# Processing batch: 8211/8309
# ------------------------------------------------------------
# Processing batch: 8212/8309
# ------------------------------------------------------------
# Processing batch: 8213/8309
# ------------------------------------------------------------
# Processing batch: 8214/8309
# ------------------------------------------------------------
# Processing batch: 8215/8309
# ------------------------------------------------------------
# Processing batch: 8216/8309
# ------------------------------------------------------------
# Processing batch: 8217/8309
# ------------------------------------------------------------
# Processing batch: 8218/8309
# ------------------------------------------------------------
# Processing batch: 8219/8309
# ------------------------------------------------------------
# Processing batch: 8220/8309
# ------------------------------------------------------------
# Processing batch: 8221/8309
# ------------------------------------------------------------
# Processing batch: 8222/8309
# ------------------------------------------------------------
# Processing batch: 8223/8309
# ------------------------------------------------------------
# Processing batch: 8224/8309
# ------------------------------------------------------------
# Processing batch: 8225/8309
# ------------------------------------------------------------
# Processing batch: 8226/8309
# ------------------------------------------------------------
# Processing batch: 8227/8309
# ------------------------------------------------------------
# Processing batch: 8228/8309
# ------------------------------------------------------------
# Processing batch: 8229/8309
# ------------------------------------------------------------
# Processing batch: 8230/8309
# ------------------------------------------------------------
# Processing batch: 8231/8309
# ------------------------------------------------------------
# Processing batch: 8232/8309
# ------------------------------------------------------------
# Processing batch: 8233/8309
# ------------------------------------------------------------
# Processing batch: 8234/8309
# ------------------------------------------------------------
# Processing batch: 8235/8309
# ------------------------------------------------------------
# Processing batch: 8236/8309
# ------------------------------------------------------------
# Processing batch: 8237/8309
# ------------------------------------------------------------
# Processing batch: 8238/8309
# ------------------------------------------------------------
# Processing batch: 8239/8309
# ------------------------------------------------------------
# Processing batch: 8240/8309
# ------------------------------------------------------------
# Processing batch: 8241/8309
# ------------------------------------------------------------
# Processing batch: 8242/8309
# ------------------------------------------------------------
# Processing batch: 8243/8309
# ------------------------------------------------------------
# Processing batch: 8244/8309
# ------------------------------------------------------------
# Processing batch: 8245/8309
# ------------------------------------------------------------
# Processing batch: 8246/8309
# ------------------------------------------------------------
# Processing batch: 8247/8309
# ------------------------------------------------------------
# Processing batch: 8248/8309
# ------------------------------------------------------------
# Processing batch: 8249/8309
# ------------------------------------------------------------
# Processing batch: 8250/8309
# ------------------------------------------------------------
# Processing batch: 8251/8309
# ------------------------------------------------------------
# Processing batch: 8252/8309
# ------------------------------------------------------------
# Processing batch: 8253/8309
# ------------------------------------------------------------
# Processing batch: 8254/8309
# ------------------------------------------------------------
# Processing batch: 8255/8309
# ------------------------------------------------------------
# Processing batch: 8256/8309
# ------------------------------------------------------------
# Processing batch: 8257/8309
# ------------------------------------------------------------
# Processing batch: 8258/8309
# ------------------------------------------------------------
# Processing batch: 8259/8309
# ------------------------------------------------------------
# Processing batch: 8260/8309
# ------------------------------------------------------------
# Processing batch: 8261/8309
# ------------------------------------------------------------
# Processing batch: 8262/8309
# ------------------------------------------------------------
# Processing batch: 8263/8309
# ------------------------------------------------------------
# Processing batch: 8264/8309
# ------------------------------------------------------------
# Processing batch: 8265/8309
# ------------------------------------------------------------
# Processing batch: 8266/8309
# ------------------------------------------------------------
# Processing batch: 8267/8309
# ------------------------------------------------------------
# Processing batch: 8268/8309
# ------------------------------------------------------------
# Processing batch: 8269/8309
# ------------------------------------------------------------
# Processing batch: 8270/8309
# ------------------------------------------------------------
# Processing batch: 8271/8309
# ------------------------------------------------------------
# Processing batch: 8272/8309
# ------------------------------------------------------------
# Processing batch: 8273/8309
# ------------------------------------------------------------
# Processing batch: 8274/8309
# ------------------------------------------------------------
# Processing batch: 8275/8309
# ------------------------------------------------------------
# Processing batch: 8276/8309
# ------------------------------------------------------------
# Processing batch: 8277/8309
# ------------------------------------------------------------
# Processing batch: 8278/8309
# ------------------------------------------------------------
# Processing batch: 8279/8309
# ------------------------------------------------------------
# Processing batch: 8280/8309
# ------------------------------------------------------------
# Processing batch: 8281/8309
# ------------------------------------------------------------
# Processing batch: 8282/8309
# ------------------------------------------------------------
# Processing batch: 8283/8309
# ------------------------------------------------------------
# Processing batch: 8284/8309
# ------------------------------------------------------------
# Processing batch: 8285/8309
# ------------------------------------------------------------
# Processing batch: 8286/8309
# ------------------------------------------------------------
# Processing batch: 8287/8309
# ------------------------------------------------------------
# Processing batch: 8288/8309
# ------------------------------------------------------------
# Processing batch: 8289/8309
# ------------------------------------------------------------
# Processing batch: 8290/8309
# ------------------------------------------------------------
# Processing batch: 8291/8309
# ------------------------------------------------------------
# Processing batch: 8292/8309
# ------------------------------------------------------------
# Processing batch: 8293/8309
# ------------------------------------------------------------
# Processing batch: 8294/8309
# ------------------------------------------------------------
# Processing batch: 8295/8309
# ------------------------------------------------------------
# Processing batch: 8296/8309
# ------------------------------------------------------------
# Processing batch: 8297/8309
# ------------------------------------------------------------
# Processing batch: 8298/8309
# ------------------------------------------------------------
# Processing batch: 8299/8309
# ------------------------------------------------------------
# Processing batch: 8300/8309
# ------------------------------------------------------------
# Processing batch: 8301/8309
# ------------------------------------------------------------
# Processing batch: 8302/8309
# ------------------------------------------------------------
# Processing batch: 8303/8309
# ------------------------------------------------------------
# Processing batch: 8304/8309
# ------------------------------------------------------------
# Processing batch: 8305/8309
# ------------------------------------------------------------
# Processing batch: 8306/8309
# ------------------------------------------------------------
# Processing batch: 8307/8309
# ------------------------------------------------------------
# Processing batch: 8308/8309
# ------------------------------------------------------------
# Processing batch: 8309/8309
# Total Time: 66760.08387875557 seconds
