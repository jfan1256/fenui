# %% [markdown]
# #### Import Package

# %% [markdown]
# ##### Follow these steps to download Milvus: https://milvus.io/docs/install_standalone-docker.md
# ##### --> To start up milvus, cd to directory of docker-compose.yml and run: docker compose up -d --> docker compose ps
# ##### --> To shut down milvus, cd to directory of docker-compose.yml and run: docker compose down

# %%
import time
import os
import pandas as pd
import numpy as np
import ray
import json
import openai as OpenAI

from pymilvus import connections, FieldSchema, CollectionSchema, DataType, Collection, utility

from utils.system import *
from class_data.data import Data

# %% [markdown]
# #### Export Data

# %% [markdown]
# ##### --> Make sure to run format_data.ipynb and get_emb_openai.ipynb (chronologically) to get the data for this
# ##### --> Skip this if the data is already provided

# %%
# Multiple Articles per Day Open AI Embeddings
wsj_multiple_openai = Data(folder_path=get_format_data() / 'openai', file_pattern='wsj_emb_openai_*')
wsj_multiple_openai = wsj_multiple_openai.concat_files()
print(wsj_multiple_openai.shape)
# Multiple Articles per Day Data
wsj_multiple = Data(folder_path=get_format_data() / 'token', file_pattern='wsj_tokens_*')
wsj_multiple = wsj_multiple.concat_files()
print(wsj_multiple.shape)

# %%
# Merge Embeddings and Article
wsj_combine = pd.concat([wsj_multiple_openai, wsj_multiple], axis=1)

# %%
# Set limit to the exact same value used in embedding_similarity.ipynb to align indexes
limit = 30
count = wsj_combine.groupby(wsj_combine.index)['accession_number'].count()
valid_dates_mask = count >= limit
wsj_combine = wsj_combine[wsj_combine.index.isin(count[valid_dates_mask].index)]
print(wsj_combine.shape)

# %%
# Add IDs
wsj_combine = wsj_combine.reset_index()
wsj_combine = wsj_combine.rename(columns={'index':'date'})
wsj_combine.index.names = ['id']
wsj_combine = wsj_combine.reset_index().set_index(['id', 'date'])
# Add article count
wsj_combine['article_count'] = wsj_combine.groupby(level='date')['body_txt'].transform('count')

# %%
# Export Data
chunks = np.array_split(wsj_combine, 50)
for i, df in enumerate(chunks, 1):
    print(i)
    df.to_parquet(get_format_data() / 'web' / f'wsj_all_{i}.parquet.brotli', compression='brotli')

# %% [markdown]
# #### Load Data

# %%
# Multiple Articles per Day Open AI Embeddings
wsj_combine = Data(folder_path=get_format_data() / 'web', file_pattern='wsj_all_*')
wsj_combine = wsj_combine.concat_files()
wsj_combine.shape
# Out:
# (830899, 6)

# %% [markdown]
# #### Milvus Add Data

# %%
def db_add_group(group):
    # Create lists for bulk insertion
    ids = []
    dates = []
    headlines = []
    documents = []
    n_tokens = []
    n_dates = []
    embeddings = []
    for row in group.iterrows():
        ids.append(row[0][0])
        dates.append(row[0][1].strftime("%Y-%m-%d"))
        headlines.append(row[1]['headline'])
        documents.append(row[1]['body_txt'])
        n_tokens.append(row[1]['n_tokens'])
        n_dates.append(row[1]['article_count'])
        embeddings.append(row[1]['ada_embedding'].tolist())

    # Prepare the data for insertion
    insert_data = [
        ids, dates, headlines, documents, n_tokens, n_dates, embeddings
    ]

    # Bulk add to collection
    collection.insert(insert_data)

def db_add_all(df, group_size):
    # Calculate the total number of groups
    total_groups = int(np.ceil(len(df) / group_size))
    print(f"Total groups: {total_groups}")

    for group_idx in range(total_groups):
        print("-" * 60)
        print(f"Processing group: {group_idx + 1}/{total_groups}")

        # Create group
        group_start = group_idx * group_size
        group_end = min(group_start + group_size, len(df))
        group = df[group_start:group_end]

        # Add group
        db_add_group(group)

# %%
# Local Start
COLLECTION_NAME = 'wsj_emb'
DIMENSION = 1536
COUNT = 100 
MILVUS_HOST = 'localhost'
MILVUS_PORT = '19530'
OPENAI_ENGINE = 'text-embedding-ada-002'
API_KEY = json.load(open(get_config() / 'api.json'))['openai_api_key']

# %%
# Cloud Start
COLLECTION_NAME = 'wsj_emb'
DIMENSION = 1536
COUNT = 100 
MILVUS_HOST = json.load(open(get_config() / 'milvus.json'))['gcp_milvus_server'] 
MILVUS_PORT = '19530'
OPENAI_ENGINE = 'text-embedding-ada-002'
API_KEY = json.load(open(get_config() / 'api.json'))['openai_api_key']

# %%
# Connect to server
connections.connect(host=MILVUS_HOST, port=MILVUS_PORT)
# Out:
# ---------------------------------------------------------------------------
# FutureTimeoutError                        Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\narrativezoo\lib\site-packages\pymilvus\client\grpc_handler.py:133, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     132 try:
# --> 133     grpc.channel_ready_future(self._channel).result(timeout=timeout)
#     134     self._setup_identifier_interceptor(self._user, timeout=timeout)
#
# File ~\AppData\Local\anaconda3\envs\narrativezoo\lib\site-packages\grpc\_utilities.py:162, in _ChannelReadyFuture.result(self, timeout)
#     161 def result(self, timeout: Optional[float] = None) -> None:
# --> 162     self._block(timeout)
#
# File ~\AppData\Local\anaconda3\envs\narrativezoo\lib\site-packages\grpc\_utilities.py:106, in _ChannelReadyFuture._block(self, timeout)
#     105 if remaining < 0:
# --> 106     raise grpc.FutureTimeoutError()
#     107 else:
#
# FutureTimeoutError:
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Connect to server
# ----> 2 connections.connect(host=MILVUS_HOST, port=MILVUS_PORT)
#
# File ~\AppData\Local\anaconda3\envs\narrativezoo\lib\site-packages\pymilvus\orm\connections.py:356, in Connections.connect(self, alias, user, password, db_name, token, **kwargs)
#     353         if parsed_uri.scheme == "https":
#     354             kwargs["secure"] = True
# --> 356     connect_milvus(**kwargs, user=user, password=password, token=token, db_name=db_name)
#     357     return
#     359 # 2nd Priority, connection configs from env
#
# File ~\AppData\Local\anaconda3\envs\narrativezoo\lib\site-packages\pymilvus\orm\connections.py:302, in Connections.connect.<locals>.connect_milvus(**kwargs)
#     299 t = kwargs.get("timeout")
#     300 timeout = t if isinstance(t, (int, float)) else Config.MILVUS_CONN_TIMEOUT
# --> 302 gh._wait_for_channel_ready(timeout=timeout)
#     303 kwargs.pop("password")
#     304 kwargs.pop("token", None)
#
# File ~\AppData\Local\anaconda3\envs\narrativezoo\lib\site-packages\pymilvus\client\grpc_handler.py:136, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     134     self._setup_identifier_interceptor(self._user, timeout=timeout)
#     135 except grpc.FutureTimeoutError as e:
# --> 136     raise MilvusException(
#     137         code=Status.CONNECT_FAILED,
#     138         message=f"Fail connecting to server on {self._address}. Timeout",
#     139     ) from e
#     140 except Exception as e:
#     141     raise e from e
#
# MilvusException: <MilvusException: (code=2, message=Fail connecting to server on 34.139.188.28:19530. Timeout)>

# %%
# Remove collection if it already exists
if utility.has_collection(COLLECTION_NAME):
    utility.drop_collection(COLLECTION_NAME)

# %%
# Create collection which includes the id, title, and embedding
fields = [
    FieldSchema(name='id', dtype=DataType.INT64, description='article id', is_primary=True, auto_id=False),
    FieldSchema(name='date', dtype=DataType.VARCHAR, description='yyyy-mm-dd date', max_length=65535),
    FieldSchema(name='headline', dtype=DataType.VARCHAR, description='article headline', max_length=65535),
    FieldSchema(name='document', dtype=DataType.VARCHAR, description='article text', max_length=65535),
    FieldSchema(name='n_token', dtype=DataType.INT64, description='number of tokens in article'),
    FieldSchema(name='n_date', dtype=DataType.INT64, description='number of articles in date'),
    FieldSchema(name='embedding', dtype=DataType.FLOAT_VECTOR, dim=DIMENSION)
]
schema = CollectionSchema(fields=fields, description='wall street journal openai embeddings')
collection = Collection(name=COLLECTION_NAME, schema=schema)

# Create an index for the collection
index_params = {
    'index_type': 'IVF_FLAT',
    'metric_type': 'COSINE',
    'params': {'nlist': 1024}
}
collection.create_index(field_name="embedding", index_params=index_params)
# Out:
# Status(code=0, message=)

# %%
# Insert data into collection
db_add_all(df=wsj_combine, group_size=5000)
# Out:
# Total groups: 167
# ------------------------------------------------------------
# Processing group: 1/167
# ------------------------------------------------------------
# Processing group: 2/167
# ------------------------------------------------------------
# Processing group: 3/167
# ------------------------------------------------------------
# Processing group: 4/167
# ------------------------------------------------------------
# Processing group: 5/167
# ------------------------------------------------------------
# Processing group: 6/167
# ------------------------------------------------------------
# Processing group: 7/167
# ------------------------------------------------------------
# Processing group: 8/167
# ------------------------------------------------------------
# Processing group: 9/167
# ------------------------------------------------------------
# Processing group: 10/167
# ------------------------------------------------------------
# Processing group: 11/167
# ------------------------------------------------------------
# Processing group: 12/167
# ------------------------------------------------------------
# Processing group: 13/167
# ------------------------------------------------------------
# Processing group: 14/167
# ------------------------------------------------------------
# Processing group: 15/167
# ------------------------------------------------------------
# Processing group: 16/167
# ------------------------------------------------------------
# Processing group: 17/167
# ------------------------------------------------------------
# Processing group: 18/167
# ------------------------------------------------------------
# Processing group: 19/167
# ------------------------------------------------------------
# Processing group: 20/167
# ------------------------------------------------------------
# Processing group: 21/167
# ------------------------------------------------------------
# Processing group: 22/167
# ------------------------------------------------------------
# Processing group: 23/167
# ------------------------------------------------------------
# Processing group: 24/167
# ------------------------------------------------------------
# Processing group: 25/167
# ------------------------------------------------------------
# Processing group: 26/167
# ------------------------------------------------------------
# Processing group: 27/167
# ------------------------------------------------------------
# Processing group: 28/167
# ------------------------------------------------------------
# Processing group: 29/167
# ------------------------------------------------------------
# Processing group: 30/167
# ------------------------------------------------------------
# Processing group: 31/167
# ------------------------------------------------------------
# Processing group: 32/167
# ------------------------------------------------------------
# Processing group: 33/167
# ------------------------------------------------------------
# Processing group: 34/167
# ------------------------------------------------------------
# Processing group: 35/167
# ------------------------------------------------------------
# Processing group: 36/167
# ------------------------------------------------------------
# Processing group: 37/167
# ------------------------------------------------------------
# Processing group: 38/167
# ------------------------------------------------------------
# Processing group: 39/167
# ------------------------------------------------------------
# Processing group: 40/167
# ------------------------------------------------------------
# Processing group: 41/167
# ------------------------------------------------------------
# Processing group: 42/167
# ------------------------------------------------------------
# Processing group: 43/167
# ------------------------------------------------------------
# Processing group: 44/167
# ------------------------------------------------------------
# Processing group: 45/167
# ------------------------------------------------------------
# Processing group: 46/167
# ------------------------------------------------------------
# Processing group: 47/167
# ------------------------------------------------------------
# Processing group: 48/167
# ------------------------------------------------------------
# Processing group: 49/167
# ------------------------------------------------------------
# Processing group: 50/167
# ------------------------------------------------------------
# Processing group: 51/167
# ------------------------------------------------------------
# Processing group: 52/167
# ------------------------------------------------------------
# Processing group: 53/167
# ------------------------------------------------------------
# Processing group: 54/167
# ------------------------------------------------------------
# Processing group: 55/167
# ------------------------------------------------------------
# Processing group: 56/167
# ------------------------------------------------------------
# Processing group: 57/167
# ------------------------------------------------------------
# Processing group: 58/167
# ------------------------------------------------------------
# Processing group: 59/167
# ------------------------------------------------------------
# Processing group: 60/167
# ------------------------------------------------------------
# Processing group: 61/167
# ------------------------------------------------------------
# Processing group: 62/167
# ------------------------------------------------------------
# Processing group: 63/167
# ------------------------------------------------------------
# Processing group: 64/167
# ------------------------------------------------------------
# Processing group: 65/167
# ------------------------------------------------------------
# Processing group: 66/167
# ------------------------------------------------------------
# Processing group: 67/167
# ------------------------------------------------------------
# Processing group: 68/167
# ------------------------------------------------------------
# Processing group: 69/167
# ------------------------------------------------------------
# Processing group: 70/167
# ------------------------------------------------------------
# Processing group: 71/167
# ------------------------------------------------------------
# Processing group: 72/167
# ------------------------------------------------------------
# Processing group: 73/167
# ------------------------------------------------------------
# Processing group: 74/167
# ------------------------------------------------------------
# Processing group: 75/167
# ------------------------------------------------------------
# Processing group: 76/167
# ------------------------------------------------------------
# Processing group: 77/167
# ------------------------------------------------------------
# Processing group: 78/167
# ------------------------------------------------------------
# Processing group: 79/167
# ------------------------------------------------------------
# Processing group: 80/167
# ------------------------------------------------------------
# Processing group: 81/167
# ------------------------------------------------------------
# Processing group: 82/167
# ------------------------------------------------------------
# Processing group: 83/167
# ------------------------------------------------------------
# Processing group: 84/167
# ------------------------------------------------------------
# Processing group: 85/167
# ------------------------------------------------------------
# Processing group: 86/167
# ------------------------------------------------------------
# Processing group: 87/167
# ------------------------------------------------------------
# Processing group: 88/167
# ------------------------------------------------------------
# Processing group: 89/167
# ------------------------------------------------------------
# Processing group: 90/167
# ------------------------------------------------------------
# Processing group: 91/167
# ------------------------------------------------------------
# Processing group: 92/167
# ------------------------------------------------------------
# Processing group: 93/167
# ------------------------------------------------------------
# Processing group: 94/167
# ------------------------------------------------------------
# Processing group: 95/167
# ------------------------------------------------------------
# Processing group: 96/167
# ------------------------------------------------------------
# Processing group: 97/167
# ------------------------------------------------------------
# Processing group: 98/167
# ------------------------------------------------------------
# Processing group: 99/167
# ------------------------------------------------------------
# Processing group: 100/167
# ------------------------------------------------------------
# Processing group: 101/167
# ------------------------------------------------------------
# Processing group: 102/167
# ------------------------------------------------------------
# Processing group: 103/167
# ------------------------------------------------------------
# Processing group: 104/167
# ------------------------------------------------------------
# Processing group: 105/167
# ------------------------------------------------------------
# Processing group: 106/167
# ------------------------------------------------------------
# Processing group: 107/167
# ------------------------------------------------------------
# Processing group: 108/167
# ------------------------------------------------------------
# Processing group: 109/167
# ------------------------------------------------------------
# Processing group: 110/167
# ------------------------------------------------------------
# Processing group: 111/167
# ------------------------------------------------------------
# Processing group: 112/167
# ------------------------------------------------------------
# Processing group: 113/167
# ------------------------------------------------------------
# Processing group: 114/167
# ------------------------------------------------------------
# Processing group: 115/167
# ------------------------------------------------------------
# Processing group: 116/167
# ------------------------------------------------------------
# Processing group: 117/167
# ------------------------------------------------------------
# Processing group: 118/167
# ------------------------------------------------------------
# Processing group: 119/167
# ------------------------------------------------------------
# Processing group: 120/167
# ------------------------------------------------------------
# Processing group: 121/167
# ------------------------------------------------------------
# Processing group: 122/167
# ------------------------------------------------------------
# Processing group: 123/167
# ------------------------------------------------------------
# Processing group: 124/167
# ------------------------------------------------------------
# Processing group: 125/167
# ------------------------------------------------------------
# Processing group: 126/167
# ------------------------------------------------------------
# Processing group: 127/167
# ------------------------------------------------------------
# Processing group: 128/167
# ------------------------------------------------------------
# Processing group: 129/167
# ------------------------------------------------------------
# Processing group: 130/167
# ------------------------------------------------------------
# Processing group: 131/167
# ------------------------------------------------------------
# Processing group: 132/167
# ------------------------------------------------------------
# Processing group: 133/167
# ------------------------------------------------------------
# Processing group: 134/167
# ------------------------------------------------------------
# Processing group: 135/167
# ------------------------------------------------------------
# Processing group: 136/167
# ------------------------------------------------------------
# Processing group: 137/167
# ------------------------------------------------------------
# Processing group: 138/167
# ------------------------------------------------------------
# Processing group: 139/167
# ------------------------------------------------------------
# Processing group: 140/167
# ------------------------------------------------------------
# Processing group: 141/167
# ------------------------------------------------------------
# Processing group: 142/167
# ------------------------------------------------------------
# Processing group: 143/167
# ------------------------------------------------------------
# Processing group: 144/167
# ------------------------------------------------------------
# Processing group: 145/167
# ------------------------------------------------------------
# Processing group: 146/167
# ------------------------------------------------------------
# Processing group: 147/167
# ------------------------------------------------------------
# Processing group: 148/167
# ------------------------------------------------------------
# Processing group: 149/167
# ------------------------------------------------------------
# Processing group: 150/167
# ------------------------------------------------------------
# Processing group: 151/167
# ------------------------------------------------------------
# Processing group: 152/167
# ------------------------------------------------------------
# Processing group: 153/167
# ------------------------------------------------------------
# Processing group: 154/167
# ------------------------------------------------------------
# Processing group: 155/167
# ------------------------------------------------------------
# Processing group: 156/167
# ------------------------------------------------------------
# Processing group: 157/167
# ------------------------------------------------------------
# Processing group: 158/167
# ------------------------------------------------------------
# Processing group: 159/167
# ------------------------------------------------------------
# Processing group: 160/167
# ------------------------------------------------------------
# Processing group: 161/167
# ------------------------------------------------------------
# Processing group: 162/167
# ------------------------------------------------------------
# Processing group: 163/167
# ------------------------------------------------------------
# Processing group: 164/167
# ------------------------------------------------------------
# Processing group: 165/167
# ------------------------------------------------------------
# Processing group: 166/167
# ------------------------------------------------------------
# Processing group: 167/167
